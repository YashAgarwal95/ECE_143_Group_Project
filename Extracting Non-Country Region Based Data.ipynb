# %% [markdown]
# The original File EdStatsData.csv has the data in many differnt groups, such as regions like Arab World, East Asia and Pacific etc,
# income groups like low income, high income etc and according to countries as well.
# After careful analysis of the data we realize that its is better to use the group based data and drop the country specific data.
# This is because the group based data gives us the relevant correlations between wealth and education while freeing us from the
# country data which hard to manage and vizualize as there are 216 countries and areas.

# %%
import pandas as pd

# %%
#reading the original file
df = pd.read_csv("EdStatsData.csv")

# %%
df
# Out:
#        Country Name Country Code  \
# 0        Arab World          ARB
# 1        Arab World          ARB
# 2        Arab World          ARB
# 3        Arab World          ARB
# 4        Arab World          ARB
# 5        Arab World          ARB
# 6        Arab World          ARB
# 7        Arab World          ARB
# 8        Arab World          ARB
# 9        Arab World          ARB
# 10       Arab World          ARB
# 11       Arab World          ARB
# 12       Arab World          ARB
# 13       Arab World          ARB
# 14       Arab World          ARB
# 15       Arab World          ARB
# 16       Arab World          ARB
# 17       Arab World          ARB
# 18       Arab World          ARB
# 19       Arab World          ARB
# 20       Arab World          ARB
# 21       Arab World          ARB
# 22       Arab World          ARB
# 23       Arab World          ARB
# 24       Arab World          ARB
# 25       Arab World          ARB
# 26       Arab World          ARB
# ...

# %%
print(len(df["Indicator Name"]))
print(type(df["Indicator Name"]))
print(type(df["Indicator Name"][3]))
# Out:
# 886930
# <class 'pandas.core.series.Series'>
# <class 'str'>

# %%
new_df = df.loc[:91624]
new_df.to_csv('primary.csv')

# %%
print(len(df["Indicator Name"]) - len(new_df["Indicator Name"]))
# Out:
# 795305

# %%
print((len(df["Indicator Name"]) - len(new_df["Indicator Name"]))/len(df["Indicator Name"]))
# Out:
# 0.8966942148760331

# %% [markdown]
# As we see above, we reduce the file size by nearly 89.7% while still keeping the relevant data
